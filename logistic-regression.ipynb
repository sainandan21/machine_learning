# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('/Users/sainandanmamidi/Downloads/insurance_data.csv')
df
# Out:
#     age  bought_insurance
# 0    23                 0
# 1    21                 0
# 2    48                 0
# 3    46                 1
# 4    53                 1
# 5    18                 0
# 6    25                 1
# 7    39                 0
# 8    67                 1
# 9    70                 1
# 10   77                 1
# 11   56                 1
# 12   61                 1
# 13   59                 1
# 14   49                 0

# %%
plt.scatter(df.age,df.bought_insurance, marker='+', color='red')

# %%
df.shape
# Out:
# (15, 2)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(df[['age']],df.bought_insurance,test_size=0.1)

# %%
x_train
# Out:
# (13, 1)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict([[88]])
# Out:
# /Users/sainandanmamidi/anaconda3/lib/python3.11/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
model.score(x_test,y_test)
# Out:
# 1.0

# %%
model.predict_proba([[100]])
# Out:
# /Users/sainandanmamidi/anaconda3/lib/python3.11/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([[0.0042533, 0.9957467]])

# %%
data = pd.read_csv('/Users/sainandanmamidi/Downloads/flood.csv')
data
# Out:
#        MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0                     3                   8                6              6
# 1                     8                   4                5              7
# 2                     3                  10                4              1
# 3                     4                   4                2              7
# 4                     3                   7                5              2
# ...                 ...                 ...              ...            ...
# 49995                 3                   7                4              7
# 49996                 3                  10                3              8
# 49997                 4                   4                5              7
# 49998                 4                   5                4              4
# 49999                 4                   5                6              3
#
# ...

# %%
plt.scatter(data.RiverManagement,data.FloodProbability, marker='+', color='red')
plt.scatter(data.ClimateChange,data.FloodProbability, marker='+', color='red')

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(data.iloc[:, :-1],data.FloodProbability,test_size=0.1)

# %%
x_train
# Out:
#        MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 33120                 1                   1                2              5
# 47662                 6                   5                6              8
# 31244                 6                   4                5              7
# 25875                 6                   9                4              2
# 32985                 2                   4                3              7
# ...                 ...                 ...              ...            ...
# 34328                 3                   5                6              7
# 44091                12                  10                8              3
# 39376                 9                   6                7              3
# 35000                 5                   3                3              4
# 36210                 8                   3                3              6
#
# ...

# %%
y_train
# Out:
# 33120    0.485
# 47662    0.555
# 31244    0.530
# 25875    0.500
# 32985    0.455
#          ...
# 34328    0.475
# 44091    0.610
# 39376    0.510
# 35000    0.405
# 36210    0.550
# Name: FloodProbability, Length: 45000, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
data_model = LinearRegression()

# %%
data_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
data_model.predict([[4,3,3,3,3,1,3,3,1,3,3,2,4,5,3,5,1,8,7,5]])
# Out:
# /Users/sainandanmamidi/anaconda3/lib/python3.11/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([0.35])

# %%
data_model.score(x_train,y_train)
# Out:
# 1.0
